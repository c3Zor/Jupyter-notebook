# %% [markdown]
# # Twitter data

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %%
import pickle
import os

# %%
if not os.path.exists('secret_twitter_credentials.pkl'):
    Twitter={}
    Twitter['Consumer Key'] =' '
    Twitter['Consumer Secret'] =' '
    Twitter['Access Token'] = ' '
    Twitter['Access Token Secret'] = ' '
    with open('secret_twitter_credentials.pkl','wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter=pickle.load(open('secret_twitter_credentials.pkl','rb'))

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
# !pip install twitter
# Out:
# Requirement already satisfied: twitter in d:\users\popis\anaconda3\lib\site-packages (1.18.0)

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x0000022C8279C048>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
LOCAL_WOE_ID=2487889

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)

# %%
world_trends[:2]
# Out:
# [{'trends': [{'name': '#BTS_BBMAs',
#     'url': 'http://twitter.com/search?q=%23BTS_BBMAs',
#     'promoted_content': None,
#     'query': '%23BTS_BBMAs',
#     'tweet_volume': 1266536},
#    {'name': '#InMyBloodVideo',
#     'url': 'http://twitter.com/search?q=%23InMyBloodVideo',
#     'promoted_content': None,
#     'query': '%23InMyBloodVideo',
#     'tweet_volume': 57695},
#    {'name': '#تذاكر_السينما_ب_١٣٠',
#     'url': 'http://twitter.com/search?q=%23%D8%AA%D8%B0%D8%A7%D9%83%D8%B1_%D8%A7%D9%84%D8%B3%D9%8A%D9%86%D9%85%D8%A7_%D8%A8_%D9%A1%D9%A3%D9%A0',
#     'promoted_content': None,
#     'query': '%23%D8%AA%D8%B0%D8%A7%D9%83%D8%B1_%D8%A7%D9%84%D8%B3%D9%8A%D9%86%D9%85%D8%A7_%D8%A8_%D9%A1%D9%A3%D9%A0',
#     'tweet_volume': 53865},
#    {'name': '#FelizMartes',
#     'url': 'http://twitter.com/search?q=%23FelizMartes',
#     'promoted_content': None,
#     'query': '%23FelizMartes',
#     'tweet_volume': 49602},
#    {'name': '#حط_صورتك_وانت_صغير',
#     'url': 'http://twitter.com/search?q=%23%D8%AD%D8%B7_%D8%B5%D9%88%D8%B1%D8%AA%D9%83_%D9%88%D8%A7%D9%86%D8%AA_%D8%B5%D8%BA%D9%8A%D8%B1',
#     'promoted_content': None,
#     'query': '%23%D8%AD%D8%B7_%D8%B5%D9%88%D8%B1%D8%AA%D9%83_%D9%88%D8%A7%D9%86%D8%AA_%D8%B5%D8%BA%D9%8A%D8%B1',
#     'tweet_volume': 78647},
#    {'name': 'Ronny Jackson',
#     'url': 'http://twitter.com/search?q=%22Ronny+Jackson%22',
#     'promoted_content': None,
#     'query': '%22Ronny+Jackson%22',
#     'tweet_volume': 57313},
#    {'name': 'Henri Michel',
#     'url': 'http://twitter.com/search?q=%22Henri+Michel%22',
#     'promoted_content': None,
#     'query': '%22Henri+Michel%22',
#     'tweet_volume': 17180},
#    {'name': 'Bülent Arınç',
#     'url': 'http://twitter.com/search?q=%22B%C3%BClent+Ar%C4%B1n%C3%A7%22',
#     'promoted_content': None,
#     'query': '%22B%C3%BClent+Ar%C4%B1n%C3%A7%22',
#     'tweet_volume': None},
#    {'name': 'France Football',
#     'url': 'http://twitter.com/search?q=%22France+Football%22',
#     'promoted_content': None,
#     'query': '%22France+Football%22',
#     'tweet_volume': None},
#    {'name': 'Mike Francesa',
#     'url': 'http://twitter.com/search?q=%22Mike+Francesa%22',
#     'promoted_content': None,
#     'query': '%22Mike+Francesa%22',
#     'tweet_volume': None},
#    {'name': 'Aziz Yıldırım',
#     'url': 'http://twitter.com/search?q=%22Aziz+Y%C4%B1ld%C4%B1r%C4%B1m%22',
#     'promoted_content': None,
#     'query': '%22Aziz+Y%C4%B1ld%C4%B1r%C4%B1m%22',
#     'tweet_volume': 32409},
#    {'name': 'Lucho Jara',
#     'url': 'http://twitter.com/search?q=%22Lucho+Jara%22',
#     'promoted_content': None,
#     'query': '%22Lucho+Jara%22',
#     'tweet_volume': None},
#    {'name': '#24Abr',
#     'url': 'http://twitter.com/search?q=%2324Abr',
#     'promoted_content': None,
#     'query': '%2324Abr',
#     'tweet_volume': 30972},
#    {'name': '#TuesdayThoughts',
#     'url': 'http://twitter.com/search?q=%23TuesdayThoughts',
#     'promoted_content': None,
#     'query': '%23TuesdayThoughts',
#     'tweet_volume': 101867},
#    {'name': '#DescribeTwitterBadly',
#     'url': 'http://twitter.com/search?q=%23DescribeTwitterBadly',
#     'promoted_content': None,
#     'query': '%23DescribeTwitterBadly',
#     'tweet_volume': None},
#    {'name': '#MIvSRH',
#     'url': 'http://twitter.com/search?q=%23MIvSRH',
#     'promoted_content': None,
#     'query': '%23MIvSRH',
#     'tweet_volume': 14027},
#    {'name': '#ElDebateEconomico',
#     'url': 'http://twitter.com/search?q=%23ElDebateEconomico',
#     'promoted_content': None,
#     'query': '%23ElDebateEconomico',
#     'tweet_volume': 13342},
#    {'name': '#GraciasAlfredyAmaia',
#     'url': 'http://twitter.com/search?q=%23GraciasAlfredyAmaia',
#     'promoted_content': None,
#     'query': '%23GraciasAlfredyAmaia',
#     'tweet_volume': 32272},
#    {'name': '#cityMW',
#     'url': 'http://twitter.com/search?q=%23cityMW',
#     'promoted_content': None,
#     'query': '%23cityMW',
#     'tweet_volume': 23927},
#    {'name': '#YouAreWinningWhen',
#     'url': 'http://twitter.com/search?q=%23YouAreWinningWhen',
#     'promoted_content': None,
#     'query': '%23YouAreWinningWhen',
#     'tweet_volume': 16992},
#    {'name': '#NoSomosTresSomosTodxs',
#     'url': 'http://twitter.com/search?q=%23NoSomosTresSomosTodxs',
#     'promoted_content': None,
#     'query': '%23NoSomosTresSomosTodxs',
#     'tweet_volume': 11423},
#    {'name': '#الحب_صدق_او_كذب',
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D8%AD%D8%A8_%D8%B5%D8%AF%D9%82_%D8%A7%D9%88_%D9%83%D8%B0%D8%A8',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D9%84%D8%AD%D8%A8_%D8%B5%D8%AF%D9%82_%D8%A7%D9%88_%D9%83%D8%B0%D8%A8',
#     'tweet_volume': 14302},
#    {'name': '#SMWNYC',
#     'url': 'http://twitter.com/search?q=%23SMWNYC',
#     'promoted_content': None,
#     'query': '%23SMWNYC',
#     'tweet_volume': None},
#    {'name': '#EsMolestoCuandoAlguien',
#     'url': 'http://twitter.com/search?q=%23EsMolestoCuandoAlguien',
#     'promoted_content': None,
#     'query': '%23EsMolestoCuandoAlguien',
#     'tweet_volume': None},
#    {'name': '#AbortoNosotrasDecidimos',
#     'url': 'http://twitter.com/search?q=%23AbortoNosotrasDecidimos',
#     'promoted_content': None,
#     'query': '%23AbortoNosotrasDecidimos',
#     'tweet_volume': None},
#    {'name': '#DuduestamoscomVocê',
#     'url': 'http://twitter.com/search?q=%23DuduestamoscomVoc%C3%AA',
#     'promoted_content': None,
#     'query': '%23DuduestamoscomVoc%C3%AA',
#     'tweet_volume': None},
#    {'name': '#TenhoTendênciaPra',
#     'url': 'http://twitter.com/search?q=%23TenhoTend%C3%AAnciaPra',
#     'promoted_content': None,
#     'query': '%23TenhoTend%C3%AAnciaPra',
#     'tweet_volume': 10022},
#    {'name': '#TDR2018',
#     'url': 'http://twitter.com/search?q=%23TDR2018',
#     'promoted_content': None,
#     'query': '%23TDR2018',
#     'tweet_volume': None},
#    {'name': '#내가_음료수가_된다면',
#     'url': 'http://twitter.com/search?q=%23%EB%82%B4%EA%B0%80_%EC%9D%8C%EB%A3%8C%EC%88%98%EA%B0%80_%EB%90%9C%EB%8B%A4%EB%A9%B4',
#     'promoted_content': None,
#     'query': '%23%EB%82%B4%EA%B0%80_%EC%9D%8C%EB%A3%8C%EC%88%98%EA%B0%80_%EB%90%9C%EB%8B%A4%EB%A9%B4',
#     'tweet_volume': None},
#    {'name': '#Martina',
#     'url': 'http://twitter.com/search?q=%23Martina',
#     'promoted_content': None,
#     'query': '%23Martina',
#     'tweet_volume': None},
#    {'name': '#HowMyBodyTellsMeImOld',
#     'url': 'http://twitter.com/search?q=%23HowMyBodyTellsMeImOld',
#     'promoted_content': None,
#     'query': '%23HowMyBodyTellsMeImOld',
#     'tweet_volume': None},
#    {'name': '#SMTMThailand',
#     'url': 'http://twitter.com/search?q=%23SMTMThailand',
#     'promoted_content': None,
#     'query': '%23SMTMThailand',
#     'tweet_volume': 331291},
#    {'name': '#Kreuz',
#     'url': 'http://twitter.com/search?q=%23Kreuz',
#     'promoted_content': None,
#     'query': '%23Kreuz',
#     'tweet_volume': None},
#    {'name': '#กาหลมหรทึก',
#     'url': 'http://twitter.com/search?q=%23%E0%B8%81%E0%B8%B2%E0%B8%AB%E0%B8%A5%E0%B8%A1%E0%B8%AB%E0%B8%A3%E0%B8%97%E0%B8%B6%E0%B8%81',
#     'promoted_content': None,
#     'query': '%23%E0%B8%81%E0%B8%B2%E0%B8%AB%E0%B8%A5%E0%B8%A1%E0%B8%AB%E0%B8%A3%E0%B8%97%E0%B8%B6%E0%B8%81',
#     'tweet_volume': 122205},
#    {'name': '#RahulDaresModi',
#     'url': 'http://twitter.com/search?q=%23RahulDaresModi',
#     'promoted_content': None,
#     'query': '%23RahulDaresModi',
#     'tweet_volume': 12763},
#    {'name': '#خسران_يامعاند_السعوديه',
#     'url': 'http://twitter.com/search?q=%23%D8%AE%D8%B3%D8%B1%D8%A7%D9%86_%D9%8A%D8%A7%D9%85%D8%B9%D8%A7%D9%86%D8%AF_%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D9%87',
#     'promoted_content': None,
#     'query': '%23%D8%AE%D8%B3%D8%B1%D8%A7%D9%86_%D9%8A%D8%A7%D9%85%D8%B9%D8%A7%D9%86%D8%AF_%D8%A7%D9%84%D8%B3%D8%B9%D9%88%D8%AF%D9%8A%D9%87',
#     'tweet_volume': None},
#    {'name': '#MiSerieFavoritaEs',
#     'url': 'http://twitter.com/search?q=%23MiSerieFavoritaEs',
#     'promoted_content': None,
#     'query': '%23MiSerieFavoritaEs',
#     'tweet_volume': None},
#    {'name': '#myhandlexplained',
#     'url': 'http://twitter.com/search?q=%23myhandlexplained',
#     'promoted_content': None,
#     'query': '%23myhandlexplained',
#     'tweet_volume': None},
#    {'name': '#ليله_الخمسه_والهروب_الكبير',
#     'url': 'http://twitter.com/search?q=%23%D9%84%D9%8A%D9%84%D9%87_%D8%A7%D9%84%D8%AE%D9%85%D8%B3%D9%87_%D9%88%D8%A7%D9%84%D9%87%D8%B1%D9%88%D8%A8_%D8%A7%D9%84%D9%83%D8%A8%D9%8A%D8%B1',
#     'promoted_content': None,
#     'query': '%23%D9%84%D9%8A%D9%84%D9%87_%D8%A7%D9%84%D8%AE%D9%85%D8%B3%D9%87_%D9%88%D8%A7%D9%84%D9%87%D8%B1%D9%88%D8%A8_%D8%A7%D9%84%D9%83%D8%A8%D9%8A%D8%B1',
#     'tweet_volume': 30689},
#    {'name': '#kathyszaboenbv',
#     'url': 'http://twitter.com/search?q=%23kathyszaboenbv',
#     'promoted_content': None,
#     'query': '%23kathyszaboenbv',
#     'tweet_volume': None},
#    {'name': '#EmbraceAmbition',
#     'url': 'http://twitter.com/search?q=%23EmbraceAmbition',
#     'promoted_content': None,
#     'query': '%23EmbraceAmbition',
#     'tweet_volume': None},
#    {'name': '#TravelTuesday',
#     'url': 'http://twitter.com/search?q=%23TravelTuesday',
#     'promoted_content': None,
#     'query': '%23TravelTuesday',
#     'tweet_volume': None},
#    {'name': '#GenocidioArmenio',
#     'url': 'http://twitter.com/search?q=%23GenocidioArmenio',
#     'promoted_content': None,
#     'query': '%23GenocidioArmenio',
#     'tweet_volume': None},
#    {'name': '#PodemosEresTú',
#     'url': 'http://twitter.com/search?q=%23PodemosEresT%C3%BA',
#     'promoted_content': None,
#     'query': '%23PodemosEresT%C3%BA',
#     'tweet_volume': None},
#    {'name': '#TorontoTheGood',
#     'url': 'http://twitter.com/search?q=%23TorontoTheGood',
#     'promoted_content': None,
#     'query': '%23TorontoTheGood',
#     'tweet_volume': None},
#    {'name': '#花のち晴れ',
#     'url': 'http://twitter.com/search?q=%23%E8%8A%B1%E3%81%AE%E3%81%A1%E6%99%B4%E3%82%8C',
#     'promoted_content': None,
#     'query': '%23%E8%8A%B1%E3%81%AE%E3%81%A1%E6%99%B4%E3%82%8C',
#     'tweet_volume': 28886},
#    {'name': '#AvengerInfinityWar',
#     'url': 'http://twitter.com/search?q=%23AvengerInfinityWar',
#     'promoted_content': None,
#     'query': '%23AvengerInfinityWar',
#     'tweet_volume': None},
#    {'name': '#budayasebagaipanglima',
#     'url': 'http://twitter.com/search?q=%23budayasebagaipanglima',
#     'promoted_content': None,
#     'query': '%23budayasebagaipanglima',
#     'tweet_volume': None},
#    {'name': '#MillicentFawcett',
#     'url': 'http://twitter.com/search?q=%23MillicentFawcett',
#     'promoted_content': None,
#     'query': '%23MillicentFawcett',
#     'tweet_volume': 11991},
#    {'name': '#NaGodVideoByTizzy',
#     'url': 'http://twitter.com/search?q=%23NaGodVideoByTizzy',
#     'promoted_content': None,
#     'query': '%23NaGodVideoByTizzy',
#     'tweet_volume': None}],
#   'as_of': '2018-04-24T16:01:59Z',
#   'created_at': '2018-04-24T15:55:37Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}]}]

# %%
trends=local_trends
print(type(trends))
print(list(trends[0].keys()))
print(trends[0]['trends'])
# Out:
# <class 'twitter.api.TwitterListResponse'>
# ['trends', 'as_of', 'created_at', 'locations']
# [{'name': 'Russ', 'url': 'http://twitter.com/search?q=Russ', 'promoted_content': None, 'query': 'Russ', 'tweet_volume': 73417}, {'name': '#InfinityWar', 'url': 'http://twitter.com/search?q=%23InfinityWar', 'promoted_content': None, 'query': '%23InfinityWar', 'tweet_volume': 460716}, {'name': '#MyHandleExplained', 'url': 'http://twitter.com/search?q=%23MyHandleExplained', 'promoted_content': None, 'query': '%23MyHandleExplained', 'tweet_volume': 60964}, {'name': 'Toronto', 'url': 'http://twitter.com/search?q=Toronto', 'promoted_content': None, 'query': 'Toronto', 'tweet_volume': 739638}, {'name': '#KUSINews', 'url': 'http://twitter.com/search?q=%23KUSINews', 'promoted_content': None, 'query': '%23KUSINews', 'tweet_volume': None}, {'name': '#Trump', 'url': 'http://twitter.com/search?q=%23Trump', 'promoted_content': None, 'query': '%23Trump', 'tweet_volume': 77702}, {'name': 'Waffle House', 'url': 'http://twitter.com/search?q=%22Waffle+House%22', 'promoted_content': None, 'query': '%22Waffle+House%22', 'tweet_volume': 494052}, {'name': 'bryan mitchell', 'url': 'http://twitter.com/search?q=%22bryan+mitchell%22', 'promoted_content': None, 'query': '%22bryan+mitchell%22', 'tweet_volume': None}, {'name': '#TuesdayThoughts', 'url': 'http://twitter.com/search?q=%23TuesdayThoughts', 'promoted_content': None, 'query': '%23TuesdayThoughts', 'tweet_volume': 101867}, {'name': 'Ronny Jackson', 'url': 'http://twitter.com/search?q=%22Ronny+Jackson%22', 'promoted_content': None, 'query': '%22Ronny+Jackson%22', 'tweet_volume': 57313}, {'name': 'Mike Francesa', 'url': 'http://twitter.com/search?q=%22Mike+Francesa%22', 'promoted_content': None, 'query': '%22Mike+Francesa%22', 'tweet_volume': None}, {'name': 'Schoolhouse Rock', 'url': 'http://twitter.com/search?q=%22Schoolhouse+Rock%22', 'promoted_content': None, 'query': '%22Schoolhouse+Rock%22', 'tweet_volume': None}, {'name': 'Olivier Vernon', 'url': 'http://twitter.com/search?q=%22Olivier+Vernon%22', 'promoted_content': None, 'query': '%22Olivier+Vernon%22', 'tweet_volume': None}, {'name': 'Amazon Key', 'url': 'http://twitter.com/search?q=%22Amazon+Key%22', 'promoted_content': None, 'query': '%22Amazon+Key%22', 'tweet_volume': None}, {'name': 'Sterling Shepard', 'url': 'http://twitter.com/search?q=%22Sterling+Shepard%22', 'promoted_content': None, 'query': '%22Sterling+Shepard%22', 'tweet_volume': None}, {'name': 'Nick Mangold', 'url': 'http://twitter.com/search?q=%22Nick+Mangold%22', 'promoted_content': None, 'query': '%22Nick+Mangold%22', 'tweet_volume': None}, {'name': 'Pat Shurmur', 'url': 'http://twitter.com/search?q=%22Pat+Shurmur%22', 'promoted_content': None, 'query': '%22Pat+Shurmur%22', 'tweet_volume': None}, {'name': 'Janoris Jenkins', 'url': 'http://twitter.com/search?q=%22Janoris+Jenkins%22', 'promoted_content': None, 'query': '%22Janoris+Jenkins%22', 'tweet_volume': None}, {'name': 'Stupid Question', 'url': 'http://twitter.com/search?q=%22Stupid+Question%22', 'promoted_content': None, 'query': '%22Stupid+Question%22', 'tweet_volume': None}, {'name': 'Oil States', 'url': 'http://twitter.com/search?q=%22Oil+States%22', 'promoted_content': None, 'query': '%22Oil+States%22', 'tweet_volume': None}, {'name': 'My Bloody Valentine', 'url': 'http://twitter.com/search?q=%22My+Bloody+Valentine%22', 'promoted_content': None, 'query': '%22My+Bloody+Valentine%22', 'tweet_volume': None}, {'name': 'Alfie Evans', 'url': 'http://twitter.com/search?q=%22Alfie+Evans%22', 'promoted_content': None, 'query': '%22Alfie+Evans%22', 'tweet_volume': 68919}, {'name': 'Bryon Hefner', 'url': 'http://twitter.com/search?q=%22Bryon+Hefner%22', 'promoted_content': None, 'query': '%22Bryon+Hefner%22', 'tweet_volume': None}, {'name': 'Tom Hardy', 'url': 'http://twitter.com/search?q=%22Tom+Hardy%22', 'promoted_content': None, 'query': '%22Tom+Hardy%22', 'tweet_volume': 43838}, {'name': 'Marty Hurney', 'url': 'http://twitter.com/search?q=%22Marty+Hurney%22', 'promoted_content': None, 'query': '%22Marty+Hurney%22', 'twe ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print((json.dumps(us_trends[:2], indent=1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#TuesdayThoughts",
#     "url": "http://twitter.com/search?q=%23TuesdayThoughts",
#     "promoted_content": null,
#     "query": "%23TuesdayThoughts",
#     "tweet_volume": 101867
#    },
#    {
#     "name": "#DescribeTwitterBadly",
#     "url": "http://twitter.com/search?q=%23DescribeTwitterBadly",
#     "promoted_content": null,
#     "query": "%23DescribeTwitterBadly",
#     "tweet_volume": null
#    },
#    {
#     "name": "#YouAreWinningWhen",
#     "url": "http://twitter.com/search?q=%23YouAreWinningWhen",
#     "promoted_content": null,
#     "query": "%23YouAreWinningWhen",
#     "tweet_volume": 16992
#    },
#    {
#     "name": "#BTS_BBMAs",
#     "url": "http://twitter.com/search?q=%23BTS_BBMAs",
#     "promoted_content": null,
#     "query": "%23BTS_BBMAs",
#     "tweet_volume": 1266536
#    },
#    {
#     "name": "#SMWNYC",
#     "url": "http://twitter.com/search?q=%23SMWNYC",
#     "promoted_content": null,
#     "query": "%23SMWNYC",
#     "tweet_volume": null
#    },
#    {
#     "name": "Ronny Jackson",
#     "url": "http://twitter.com/search?q=%22Ronny+Jackson%22",
#     "promoted_content": null,
#     "query": "%22Ronny+Jackson%22",
#     "tweet_volume": 57313
#    },
#    {
#     "name": "Mike Francesa",
#     "url": "http://twitter.com/search?q=%22Mike+Francesa%22",
#     "promoted_content": null,
#     "query": "%22Mike+Francesa%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Schoolhouse Rock",
#     "url": "http://twitter.com/search?q=%22Schoolhouse+Rock%22",
#     "promoted_content": null,
#     "query": "%22Schoolhouse+Rock%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Olivier Vernon",
#     "url": "http://twitter.com/search?q=%22Olivier+Vernon%22",
#     "promoted_content": null,
#     "query": "%22Olivier+Vernon%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Amazon Key",
#     "url": "http://twitter.com/search?q=%22Amazon+Key%22",
#     "promoted_content": null,
#     "query": "%22Amazon+Key%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Sterling Shepard",
#     "url": "http://twitter.com/search?q=%22Sterling+Shepard%22",
#     "promoted_content": null,
#     "query": "%22Sterling+Shepard%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Nick Mangold",
#     "url": "http://twitter.com/search?q=%22Nick+Mangold%22",
#     "promoted_content": null,
#     "query": "%22Nick+Mangold%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Pat Shurmur",
#     "url": "http://twitter.com/search?q=%22Pat+Shurmur%22",
#     "promoted_content": null,
#     "query": "%22Pat+Shurmur%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Janoris Jenkins",
#     "url": "http://twitter.com/search?q=%22Janoris+Jenkins%22",
#     "promoted_content": null,
#     "query": "%22Janoris+Jenkins%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Stupid Question",
#     "url": "http://twitter.com/search?q=%22Stupid+Question%22",
#     "promoted_content": null,
#     "query": "%22Stupid+Question%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Oil States",
#     "url": "http://twitter.com/search?q=%22Oil+States%22",
#     "promoted_content": null,
#     "query": "%22Oil+States%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "My Bloody Valentine",
#     "url": "http://twitter.com/search?q=%22My+Bloody+Valentine%22",
#     "promoted_content": null,
#     "query": "%22My+Bloody+Valentine%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Alfie Evans",
#     "url": "http://twitter.com/search?q=%22Alfie+Evans%22",
#     "promoted_content": null,
#     "query": "%22Alfie+Evans%22",
#     "tweet_volume": 68919
#    },
#    {
#     "name": "Bryon Hefner",
#     "url": "http://twitter.com/search?q=%22Bryon+Hefner%22",
#     "promoted_content": null,
#     "query": "%22Bryon+Hefner%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Tom Hardy",
#     "url": "http://twitter.com/search?q=%22Tom+Hardy%22",
#     "promoted_content": null,
#     "query": "%22Tom+Hardy%22",
#     "tweet_volume": 43838
#    },
#    {
#     "name": "Marty Hurney",
#     "url": "http://twitter.com/search?q=%22Marty+Hurney%22",
#     "promoted_content": null,
#     "query": "%22Marty+Hurney%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Marcus Smart",
#     "url": "http://twitter.com/search?q=%22Marcus+Smart%22",
#     "promoted_content": null,
#     "query": "%22Marcus+Smart%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Webby",
#     "url": "http://twitter.com/search?q=Webby",
#     "promoted_content": null,
#     "query": "Webby",
#     "tweet_volume": null
#    },
#    {
#     "name": "Astacio",
#     "url": "http://twitter.com/search?q=Astacio",
#     "promoted_content": null,
#     "query": "Astacio",
#     "tweet_volume": null
#    },
#    {
#     "name": "When Jon Karl",
#     "url": "http://twitter.com/search?q=%22When+Jon+Karl%22",
#     "promoted_content": null,
#     "query": "%22When+Jon+Karl%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Bill Snyder",
#     "url": "http://twitter.com/search?q=%22Bill+Snyder%22",
#     "promoted_content": null,
#     "query": "%22Bill+Snyder%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "LEAH ON THE OFFBEAT",
#     "url": "http://twitter.com/search?q=%22LEAH+ON+THE+OFFBEAT%22",
#     "promoted_content": null,
#     "query": "%22LEAH+ON+THE+OFFBEAT%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#HowMyBodyTellsMeImOld",
#     "url": "http://twitter.com/search?q=%23HowMyBodyTellsMeImOld",
#     "promoted_content": null,
#     "query": "%23HowMyBodyTellsMeImOld",
#     "tweet_volume": null
#    },
#    {
#     "name": "#EmbraceAmbition",
#     "url": "http://twitter.com/search?q=%23EmbraceAmbition",
#     "promoted_content": null,
#     "query": "%23EmbraceAmbition",
#     "tweet_volume": null
#    },
#    {
#     "name": "#InMyBloodVideo",
#     "url": "http://twitter.com/search?q=%23InMyBloodVideo",
#     "promoted_content": null,
#     "query": "%23InMyBloodVideo",
#     "tweet_volume": 57695
#    },
#    {
#     "name": "#GSMCON2018",
#     "url": "http://twitter.com/search?q=%23GSMCON2018",
#     "promoted_content": null,
#     "query": "%23GSMCON2018",
#     "tweet_volume": null
#    },
#    {
#     "name": "#contentwritingchat",
#     "url": "http://twitter.com/search?q=%23contentwritingchat",
#     "promoted_content": null,
#     "query": "%23contentwritingchat",
#     "tweet_volume": null
#    },
#    {
#     "name": "#cityMW",
#     "url": "http://twitter.com/search?q=%23cityMW",
#     "promoted_content": null,
#     "query": "%23cityMW",
#     "tweet_volume": 23927
#    },
#    {
#     "name": "#AvengerInfinityWar",
#     "url": "http://twitter.com/search?q=%23AvengerInfinityWar",
#     "promoted_content": null,
#     "query": "%23AvengerInfinityWar",
#     "tweet_volume": null
#    },
#    {
#     "name": "#myhandlexplained",
#     "url": "http://twitter.com/search?q=%23myhandlexplained",
#     "promoted_content": null,
#     "query": "%23myhandlexplained",
#     "tweet_volume": null
#    },
#    {
#     "name": "#LeadDevNewYork",
#     "url": "http://twitter.com/search?q=%23LeadDevNewYork",
#     "promoted_content": null,
#     "query": "%23LeadDevNewYork",
#     "tweet_volume": null
#    },
#    {
#     "name": "#VenomTrailer",
#     "url": "http://twitter.com/search?q=%23VenomTrailer",
#     "promoted_content": null,
#     "query": "%23VenomTrailer",
#     "tweet_volume": null
#    },
#    {
#     "name": "#protectcleanwater",
#     "url": "http://twitter.com/search?q=%23protectcleanwater",
#     "promoted_content": null,
#     "query": "%23protectcleanwater",
#     "tweet_volume": null
#    },
#    {
#     "name": "#CLOSErikers",
#     "url": "http://twitter.com/search?q=%23CLOSErikers",
#     "promoted_content": null,
#     "query": "%23CLOSErikers",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ruralprogressive",
#     "url": "http://twitter.com/search?q=%23ruralprogressive",
#     "promoted_content": null,
#     "query": "%23ruralprogressive",
#     "tweet_volume": null
#    },
#    {
#     "name": "#WhenIWasSingle",
#     "url": "http://twitter.com/search?q=%23WhenIWasSingle",
#     "promoted_content": null,
#     "query": "%23WhenIWasSingle",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TransformationTuesday",
#     "url": "http://twitter.com/search?q=%23TransformationTuesday",
#     "promoted_content": null,
#     "query": "%23TransformationTuesday",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BookBirthday",
#     "url": "http://twitter.com/search?q=%23BookBirthday",
#     "promoted_content": null,
#     "query": "%23BookBirthday",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BHDoF",
#     "url": "http://twitter.com/search?q=%23BHDoF",
#     "promoted_content": null,
#     "query": "%23BHDoF",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Peace72",
#     "url": "http://twitter.com/search?q=%23Peace72",
#     "promoted_content": null,
#     "query": "%23Peace72",
#     "tweet_volume": null
#    },
#    {
#     "name": "#GEOINT2018",
#     "url": "http://twitter.com/search?q=%23GEOINT2018",
#     "promoted_content": null,
#     "query": "%23GEOINT2018",
#     "tweet_volume": null
#    },
#    {
#     "name": "#CUonStrike",
#     "url": "http://twitter.com/search?q=%23CUonStrike",
#     "promoted_content": null,
#     "query": "%23CUonStrike",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AM2DM",
#     "url": "http://twitter.com/search?q=%23AM2DM",
#     "promoted_content": null,
#     "query": "%23AM2DM",
#     "tweet_volume": null
#    },
#    {
#     "name": "#FelizMartes",
#     "url": "http://twitter.com/search?q=%23FelizMartes",
#     "promoted_content": null,
#     "query": "%23FelizMartes",
#     "tweet_volume": 49602
#    },
#    {
#     "name": "#AllWorkSafeWork",
#     "url": "http://twitter.com/search?q=%23AllWorkSafeWork",
#     "promoted_content": null,
#     "query": "%23AllWorkSafeWork",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2018-04-24T16:02:00Z",
#   "created_at": "2018-04-24T15:55:37Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['us'] = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

trends_set['san diego'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']])

# %%
for loc in ['world','us','san diego']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# #HowMyBodyTellsMeImOld,Henri Michel,#EsMolestoCuandoAlguien,#RahulDaresModi,#NoSomosTresSomosTodxs,#EmbraceAmbition,#MiSerieFavoritaEs,#حط_صورتك_وانت_صغير,#TravelTuesday,#AbortoNosotrasDecidimos,#MIvSRH,#PodemosEresTú,#ElDebateEconomico,#DuduestamoscomVocê,#TorontoTheGood,#Martina,#DescribeTwitterBadly,#SMTMThailand,Ronny Jackson,#kathyszaboenbv,#24Abr,Bülent Arınç,France Football,#Kreuz,#TDR2018,#TenhoTendênciaPra,#NaGodVideoByTizzy,#MillicentFawcett,#BTS_BBMAs,Mike Francesa,#تذاكر_السينما_ب_١٣٠,#กาหลมหรทึก,#myhandlexplained,#budayasebagaipanglima,#الحب_صدق_او_كذب,Aziz Yıldırım,#ليله_الخمسه_والهروب_الكبير,#SMWNYC,#cityMW,Lucho Jara,#내가_음료수가_된다면,#GenocidioArmenio,#خسران_يامعاند_السعوديه,#花のち晴れ,#AvengerInfinityWar,#TuesdayThoughts,#YouAreWinningWhen,#InMyBloodVideo,#GraciasAlfredyAmaia,#FelizMartes
# ('----------', 'us')
# #HowMyBodyTellsMeImOld,#AM2DM,Marcus Smart,LEAH ON THE OFFBEAT,Bill Snyder,Tom Hardy,#GSMCON2018,Olivier Vernon,Marty Hurney,Pat Shurmur,#EmbraceAmbition,#CLOSErikers,Nick Mangold,Amazon Key,#AllWorkSafeWork,Oil States,#Peace72,Alfie Evans,#DescribeTwitterBadly,Sterling Shepard,Ronny Jackson,#ruralprogressive,Astacio,Janoris Jenkins,Webby,#BTS_BBMAs,#InMyBloodVideo,Stupid Question,Mike Francesa,#GEOINT2018,#myhandlexplained,Schoolhouse Rock,#VenomTrailer,#SMWNYC,#cityMW,#CUonStrike,#WhenIWasSingle,#contentwritingchat,When Jon Karl,#BookBirthday,Bryon Hefner,#AvengerInfinityWar,#TuesdayThoughts,#LeadDevNewYork,#protectcleanwater,#YouAreWinningWhen,My Bloody Valentine,#BHDoF,#TransformationTuesday,#FelizMartes
# ('----------', 'san diego')
# #HowMyBodyTellsMeImOld,#KUSINews,Marcus Smart,Tom Hardy,#GSMCON2018,Olivier Vernon,Marty Hurney,Pat Shurmur,#EmbraceAmbition,#CLOSErikers,Nick Mangold,Amazon Key,Oil States,#Peace72,Alfie Evans,#MyHandleExplained,Sterling Shepard,Ronny Jackson,#ruralprogressive,Waffle House,Astacio,Janoris Jenkins,Webby,#BTS_BBMAs,#InMyBloodVideo,Stupid Question,Mike Francesa,#GEOINT2018,bryan mitchell,Schoolhouse Rock,#VenomTrailer,#SMWNYC,#cityMW,#BHDoF,Russ,#CUonStrike,#WhenIWasSingle,Toronto,#contentwritingchat,When Jon Karl,#BookBirthday,Bryon Hefner,#TuesdayThoughts,#Trump,#LeadDevNewYork,#InfinityWar,#YouAreWinningWhen,My Bloody Valentine,#protectcleanwater,#TransformationTuesday

# %%
print(( '='*10,'intersection of world and us'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and san-diego'))
print((trends_set['san diego'].intersection(trends_set['us'])))
# Out:
# ('==========', 'intersection of world and us')
# {'#HowMyBodyTellsMeImOld', '#BTS_BBMAs', 'Mike Francesa', '#myhandlexplained', '#AvengerInfinityWar', '#DescribeTwitterBadly', '#TuesdayThoughts', '#EmbraceAmbition', '#YouAreWinningWhen', '#InMyBloodVideo', '#SMWNYC', 'Ronny Jackson', '#cityMW', '#FelizMartes'}
# ('==========', 'intersection of us and san-diego')
# {'#HowMyBodyTellsMeImOld', 'Marcus Smart', 'Tom Hardy', '#GSMCON2018', 'Olivier Vernon', 'Marty Hurney', 'Pat Shurmur', '#EmbraceAmbition', '#CLOSErikers', 'Nick Mangold', 'Amazon Key', 'Oil States', '#Peace72', 'Alfie Evans', 'Sterling Shepard', 'Ronny Jackson', '#ruralprogressive', 'Janoris Jenkins', 'Webby', '#BTS_BBMAs', '#InMyBloodVideo', 'Stupid Question', 'Mike Francesa', '#GEOINT2018', 'My Bloody Valentine', 'Schoolhouse Rock', '#VenomTrailer', '#SMWNYC', '#cityMW', '#CUonStrike', '#WhenIWasSingle', '#contentwritingchat', 'When Jon Karl', '#BookBirthday', 'Bryon Hefner', '#TuesdayThoughts', '#LeadDevNewYork', '#protectcleanwater', '#YouAreWinningWhen', 'Astacio', '#BHDoF', '#TransformationTuesday'}

# %% [markdown]
# ## Example 5. Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter

# %%
q = '#Lietuva' 

number = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=number)

statuses = search_results['statuses']

# %%
len(statuses)
#print(statuses)
# Out:
# 100

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:

# %%
all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)
# Out:
# 53

# %%
[s['text'] for s in search_results['statuses']]
# Out:
# ['#ArianaComeToLithuania #Vilnius #Kaunas #Lietuva #Lithuania Listen on @Spotify  #NoTearsLeftToCry by @ArianaGrande ♡ https://t.co/Jbzq0rYvja',
#  '#like4like #palanga #vilnius #lithuanian #litva #lietuva #lucky #luxurylife #europe #mafia… https://t.co/0Nn8rkVK0g',
#  '#Birstonas #Lithuania spring time #lietuva https://t.co/aQ9IdWaDG0',
#  'RT @WeLoveLithuania: Sakurų žydėjimas Vilniuje 2018 – Vakarinė versija\n#Vilnius\nWe love Lithuania - Photo by: Simonas Rudaminas\n#Lithuania…',
#  'Veiksme | in action 😎\n•\n•\n•\n•\n•\n•\n•\n#me #choreographer #choreografas #vilonas #lietuva… https://t.co/UMvp0ml9xf',
#  'RT @NejauNet: Shadow | #Kaunas, #Lithuania #mavicpro #Lietuva #dronas #beautifullithuania #mavic #djimavic #djieurope #Kaunascity #Kaunasae…',
#  'Morning | #Kaunas, #Lithuania #mavicpro #Lietuva #dronas #kaunasoldtown #beautifullithuania #mavic #djimavic… https://t.co/sb2sWAXJ1a',
#  'RT @WeLoveLithuania: Sakurų žydėjimas Vilniuje 2018 – Vakarinė versija\n#Vilnius\nWe love Lithuania - Photo by: Simonas Rudaminas\n#Lithuania…',
#  'RT @WeLoveLithuania: Sakurų žydėjimas Vilniuje 2018 – Vakarinė versija\n#Vilnius\nWe love Lithuania - Photo by: Simonas Rudaminas\n#Lithuania…',
#  'Sakurų žydėjimas Vilniuje 2018 – Vakarinė versija\n#Vilnius\nWe love Lithuania - Photo by: Simonas Rudaminas… https://t.co/lU2L4kTyj1',
#  'RT @NejauNet: Towers of #Kaunas old town | #Lithuania #mavicpro #Lietuva #dronas #kaunasoldtown #beautifullithuania #mavic #djimavic #djieu…',
#  'Lake Plateliai #plateliai #plunge #genesbank #lithuania #ltu #lietuva @ Plateliai https://t.co/K1XxOK6JgS',
#  "Received my great grandfather's birth record over the weekend. He was born in #Kedonys #Lithuania and baptized in t… https://t.co/wLN94sVzqB",
#  '#like4like #palanga #vilnius #lithuanian #litva #lietuva #lucky #luxurylife #europe #mafia… https://t.co/q5B4MDXvJE',
#  'RT @NejauNet: Waves | #Karklė, #Lithuania #mavicpro #Lietuva #dronas #beautifullithuania #mavic #olandokepure #djimavic #djieurope #baltijo…',
#  '#like4like #palanga #vilnius #lithuanian #litva #lietuva #lucky #luxurylife #europe #mafia… https://t.co/JyAcvXg01h',
#  'RT @Confederation_M: Vacancies:\nGR Departamento VADOVAS (#Vilnius)\nHead of the #GR Department \n#Lithuania #Lietuva #Литва #MPA_Konfederacija',
#  'RT @Confederation_M: #Eksporto Departamento VADOVAS (#Vilnius, #Kaunas)\nHead of the #Export Department\n#Lithuania #Lietuva #Литва @Confeder…',
#  'RT @Confederation_M: Vacancies of the National Confederation of Marketing, Sales and Service Professionals - MPA Konfederacijai aktualu \n#L…',
#  'RT @ValstietisToday: #LVZS #valstieciai #zalieji #proletarai #Karbauskis #rinkimai #Seimas2016 #Lietuva #Lithuania #LaikykitėsTen https://t…',
#  '#Lithuania #Lietuva #Klaipėda #DanėRiver #OldMill #Trawlers https://t.co/XnhvK8MGnx',
#  'Pirma pergalė in IIHF Ice Hockey World Chamionpship, group B!!! LTU vs CRO 3 - 0 !!! #lietuva… https://t.co/hhBrDmcgo8',
#  'Lietuvos vyriausiasis archyvaras su darbiniu vizitu lankėsi Maskvoje: https://t.co/lEbrtKMPSU\n#archyvai #archives… https://t.co/ihwUW6jjcT',
#  '#Lithuania #Lietuva #PlokštinėMissileBase #PlokštinėsRaketųBazė #SovietUnion #ColdWar… https://t.co/RZJYzbkUhH',
#  '#Lithuania #Lietuva #Šiauliai #HillOfCrosses #KryziuKalnas #Pilgrimage https://t.co/mBKIAKHu0R',
#  '#Lithuania #Lietuva #Šiauliai #HillOfCrosses #KryziuKalnas #Pilgrimage https://t.co/UrhDR06qGc',
#  '#Lithuania #Lietuva #Šiauliai #HillOfCrosses #KryziuKalnas #Pilgrimage https://t.co/zS4q6gmMv5',
#  '#Lithuania #Lietuva #Šiauliai #SundialSquare #SaulėsLaikrodžioAikštė #Archer #Šaulys #GoldenBoy… https://t.co/6tvgRQ6BHD',
#  '#Lithuania #Lietuva #Šiauliai #VilniausGatvė https://t.co/EGF7IX23IJ',
#  '#Lithuania #Lietuva #Šiauliai https://t.co/qVWjAjoIY1',
#  'Dear Kaunas, I will be with you again very shortly! 🇱🇹🛫😎 #lietuva #lithuania #kaunas https://t.co/zB3eL8n9Lu',
#  '#Lithuania #Lietuva #Kaunas #VytautasTheGreatWarMuseum #VytautoDidžiojoKaroMuziejus https://t.co/2oDbkdJsx5',
#  '#Lithuania #Lietuva #Kaunas #VytautasTheGreatWarMuseum #VytautoDidžiojoKaroMuziejus #EternalFlame https://t.co/vjgfwCUHiY',
#  'Waves | #Karklė, #Lithuania #mavicpro #Lietuva #dronas #beautifullithuania #mavic #olandokepure #djimavic… https://t.co/VnDwxbwddr',
#  'RT @NejauNet: Towers of #Kaunas old town | #Lithuania #mavicpro #Lietuva #dronas #kaunasoldtown #beautifullithuania #mavic #djimavic #djieu…',
#  'RT @NejauNet: Towers of #Kaunas old town | #Lithuania #mavicpro #Lietuva #dronas #kaunasoldtown #beautifullithuania #mavic #djimavic #djieu…',
#  'Po ilgos pertraukos pristatysiu naują laidos epizodą ateinantį šeštadienį. Kalbėsiu apie Bitonomiją ir virtualų ver… https://t.co/pIP4SyjRix',
#  'RT @NejauNet: Towers of #Kaunas old town | #Lithuania #mavicpro #Lietuva #dronas #kaunasoldtown #beautifullithuania #mavic #djimavic #djieu…',
#  'RT @NejauNet: Towers of #Kaunas old town | #Lithuania #mavicpro #Lietuva #dronas #kaunasoldtown #beautifullithuania #mavic #djimavic #djieu…',
#  'Towers of #Kaunas old town | #Lithuania #mavicpro #Lietuva #dronas #kaunasoldtown #beautifullithuania #mavic… https://t.co/KcHr3KHWwZ',
#  'Kumeliauskas izvirza "Dream team" vadībā 1:0 #Lietuva #Croatia',
#  'Kadagių slėnis 👍#Lietuva',
#  '#nofilter #Siauliai #Lithuania #Lietuva @ Šiauliai https://t.co/diTjuR4i99',
#  'Inside Plunge’s #church #plunge #lithuania #lietuva @ Plunge https://t.co/StqPVZ6AYe',
#  'RT @Confederation_M: #Labdaros ir paramos skyriaus VADOVAS (Vilnius)  Head of the Сharity and Support  #Lithuania #Lietuva #Литва #MPA_Konf…',
#  'RT @Confederation_M: Mokymo Centro PROJEKTŲ VADOVAS (Vilnius, Kaunas)\nApmokymų, įgūdžių ugdymo ir profesinio meistriškumo tobulinimo Centra…',
#  'RT @Confederation_M: Mokymo Centro VADOVAS (Vilnius, Kaunas)\nApmokymų, įgūdžių ugdymo ir profesinio meistriškumo tobulinimo Centras – MPA K…',
#  'RT @Confederation_M: Vacancies:\nGR Departamento VADOVAS (#Vilnius)\nHead of the #GR Department \n#Lithuania #Lietuva #Литва #MPA_Konfederacija',
#  'RT @Confederation_M: #Statybų ir remonto Departamento VADOVAS (#Vilnius, #Kaunas, #Klaipėda)\nHead of the #Building and #Repair Department\n#…',
#  'RT @Confederation_M: #HoReCa Departamento VADOVAS (#Kaunas, #Vilnius )\nHead of the HoReCa Department\n#Lithuania #Lietuva #Литва #MPA_Konfed…',
#  'RT @Confederation_M: #Labdaros ir paramos skyriaus VADOVAS (Vilnius)  Head of the Сharity and Support  #Lithuania #Lietuva #Литва #MPA_Konf…',
#  'RT @Confederation_M: Mokymo Centro PROJEKTŲ VADOVAS (Vilnius, Kaunas)\nApmokymų, įgūdžių ugdymo ir profesinio meistriškumo tobulinimo Centra…',
#  'RT @Confederation_M: Mokymo Centro VADOVAS (Vilnius, Kaunas)\nApmokymų, įgūdžių ugdymo ir profesinio meistriškumo tobulinimo Centras – MPA K…',
#  'RT @Confederation_M: Vacancies:\nGR Departamento VADOVAS (#Vilnius)\nHead of the #GR Department \n#Lithuania #Lietuva #Литва #MPA_Konfederacija',
#  'RT @Confederation_M: Vacancies: \n#Nekilnojamojo turto Departamento VADOVAS (#Vilnius, #Kaunas)\nHead of the #RealEstate Department\n#Lithuani…',
#  'RT @Confederation_M: #Energetikos Departamento VADOVAS (#Vilnius)\nHead of the #Energy (#LPG, #oil) Department \n#Lithuania #Lietuva #Литва #…',
#  'RT @Confederation_M: #Statybų ir remonto Departamento VADOVAS (#Vilnius, #Kaunas, #Klaipėda)\nHead of the #Building and #Repair Department\n#…',
#  'RT @Confederation_M: #HoReCa Departamento VADOVAS (#Kaunas, #Vilnius )\nHead of the HoReCa Department\n#Lithuania #Lietuva #Литва #MPA_Konfed…',
#  'RT @Confederation_M: #NewMarkets Departamento VADOVAS (#Vilnius, #Kaunas, #Klaipėda)\nHead of the NewMarket Department\n#Lithuania #Lietuva #…',
#  'RT @Confederation_M: #Eksporto Departamento VADOVAS (#Vilnius, #Kaunas)\nHead of the #Export Department\n#Lithuania #Lietuva #Литва @Confeder…',
#  'RT @ArianaGrandeLT4: #ArianaComeToLithuania #Vilnius #Kaunas #Lietuva #Lithuania Listen on @Spotify  #NoTearsLeftToCry by @ArianaGrande ♡ h…',
#  'RT @Confederation_M: #Labdaros ir paramos skyriaus VADOVAS (Vilnius)  Head of the Сharity and Support  #Lithuania #Lietuva #Литва #MPA_Konf…',
#  'RT @Confederation_M: Mokymo Centro PROJEKTŲ VADOVAS (Vilnius, Kaunas)\nApmokymų, įgūdžių ugdymo ir profesinio meistriškumo tobulinimo Centra…',
#  'RT @Confederation_M: Mokymo Centro VADOVAS (Vilnius, Kaunas)\nApmokymų, įgūdžių ugdymo ir profesinio meistriškumo tobulinimo Centras – MPA K…',
#  'RT @Confederation_M: Vacancies:\nGR Departamento VADOVAS (#Vilnius)\nHead of the #GR Department \n#Lithuania #Lietuva #Литва #MPA_Konfederacija',
#  'RT @Confederation_M: #Labdaros ir paramos skyriaus VADOVAS (Vilnius)  Head of the Сharity and Support  #Lithuania #Lietuva #Литва #MPA_Konf…',
#  'RT @Confederation_M: Vacancies: \n#Nekilnojamojo turto Departamento VADOVAS (#Vilnius, #Kaunas)\nHead of the #RealEstate Department\n#Lithuani…',
#  'RT @Confederation_M: #Energetikos Departamento VADOVAS (#Vilnius)\nHead of the #Energy (#LPG, #oil) Department \n#Lithuania #Lietuva #Литва #…',
#  'RT @Confederation_M: #HoReCa Departamento VADOVAS (#Kaunas, #Vilnius )\nHead of the HoReCa Department\n#Lithuania #Lietuva #Литва #MPA_Konfed…',
#  'RT @Confederation_M: #NewMarkets Departamento VADOVAS (#Vilnius, #Kaunas, #Klaipėda)\nHead of the NewMarket Department\n#Lithuania #Lietuva #…',
#  'RT @Confederation_M: #Eksporto Departamento VADOVAS (#Vilnius, #Kaunas)\nHead of the #Export Department\n#Lithuania #Lietuva #Литва @Confeder…',
#  'RT @Confederation_M: Vacancies of the National Confederation of Marketing, Sales and Service Professionals - MPA Konfederacijai aktualu \n#L…',
#  'RT @Confederation_M: #Eksporto Departamento VADOVAS (#Vilnius, #Kaunas)\nHead of the #Export Department\n#Lithuania #Lietuva #Литва @Confeder…',
#  'RT @Confederation_M: #NewMarkets Departamento VADOVAS (#Vilnius, #Kaunas, #Klaipėda)\nHead of the NewMarket Department\n#Lithuania #Lietuva #…',
#  'RT @Confederation_M: #HoReCa Departamento VADOVAS (#Kaunas, #Vilnius )\nHead of the HoReCa Department\n#Lithuania #Lietuva #Литва #MPA_Konfed…',
#  'RT @Confederation_M: #Statybų ir remonto Departamento VADOVAS (#Vilnius, #Kaunas, #Klaipėda)\nHead of the #Building and #Repair Department\n#…',
#  'RT @Confederation_M: #Energetikos Departamento VADOVAS (#Vilnius)\nHead of the #Energy (#LPG, #oil) Department \n#Lithuania #Lietuva #Литва #…',
#  'RT @Confederation_M: Vacancies: \n#Nekilnojamojo turto Departamento VADOVAS (#Vilnius, #Kaunas)\nHead of the #RealEstate Department\n#Lithuani…',
#  'RT @Confederation_M: Vacancies:\nGR Departamento VADOVAS (#Vilnius)\nHead of the #GR Department \n#Lithuania #Lietuva #Литва #MPA_Konfederacija',
#  'RT @Confederation_M: Mokymo Centro VADOVAS (Vilnius, Kaunas)\nApmokymų, įgūdžių ugdymo ir profesinio meistriškumo tobulinimo Centras – MPA K…',
#  'RT @Confederation_M: Mokymo Centro PROJEKTŲ VADOVAS (Vilnius, Kaunas)\nApmokymų, įgūdžių ugdymo ir profesinio meistriškumo tobulinimo Centra…',
#  'RT @Confederation_M: #Labdaros ir paramos skyriaus VADOVAS (Vilnius)  Head of the Сharity and Support  #Lithuania #Lietuva #Литва #MPA_Konf…',
#  "i didn't mean to ruin every thing \n#lithuania #lietuva #photography #sky #sunset #afternoon #lithuanianarmy #kpoper… https://t.co/LgtarunnA7",
#  '@IIHFHockey @NJDevils @NYRangers @penguins @NYIslanders @hcSKA_News @hcSKA #Lietuva !',
#  'Looking forward to this game! #Lietuva #iihf #dynamicduo https://t.co/dTBq2qIz4F',
#  'RT @Confederation_M: Vacancies of the National Confederation of Marketing, Sales and Service Professionals - MPA Konfederacijai aktualu \n#L…',
#  'RT @Confederation_M: Mokymo Centro VADOVAS (Vilnius, Kaunas)\nApmokymų, įgūdžių ugdymo ir profesinio meistriškumo tobulinimo Centras – MPA K…',
#  'RT @Confederation_M: Mokymo Centro PROJEKTŲ VADOVAS (Vilnius, Kaunas)\nApmokymų, įgūdžių ugdymo ir profesinio meistriškumo tobulinimo Centra…',
#  'RT @Confederation_M: #Labdaros ir paramos skyriaus VADOVAS (Vilnius)  Head of the Сharity and Support  #Lithuania #Lietuva #Литва #MPA_Konf…',
#  'RT @Confederation_M: Vacancies:\nGR Departamento VADOVAS (#Vilnius)\nHead of the #GR Department \n#Lithuania #Lietuva #Литва #MPA_Konfederacija',
#  'RT @Confederation_M: Vacancies: \n#Nekilnojamojo turto Departamento VADOVAS (#Vilnius, #Kaunas)\nHead of the #RealEstate Department\n#Lithuani…',
#  'RT @Confederation_M: #Energetikos Departamento VADOVAS (#Vilnius)\nHead of the #Energy (#LPG, #oil) Department \n#Lithuania #Lietuva #Литва #…',
#  'RT @Confederation_M: #Statybų ir remonto Departamento VADOVAS (#Vilnius, #Kaunas, #Klaipėda)\nHead of the #Building and #Repair Department\n#…',
#  'RT @Confederation_M: #HoReCa Departamento VADOVAS (#Kaunas, #Vilnius )\nHead of the HoReCa Department\n#Lithuania #Lietuva #Литва #MPA_Konfed…',
#  'RT @Confederation_M: #NewMarkets Departamento VADOVAS (#Vilnius, #Kaunas, #Klaipėda)\nHead of the NewMarket Department\n#Lithuania #Lietuva #…',
#  'RT @Confederation_M: #Eksporto Departamento VADOVAS (#Vilnius, #Kaunas)\nHead of the #Export Department\n#Lithuania #Lietuva #Литва @Confeder…',
#  'Ferry | #Klaipėda, #Lithuania #mavicpro #Lietuva #dronas #naujojiperkela #beautifullithuania #mavic #djimavic… https://t.co/b0pOxnIW3D',
#  'RT @NejauNet: Reflections | #Kaunas, #Lithuania #mavicpro #Lietuva #dronas #beautifullithuania #mavic #djimavic #djieurope #Kaunascity #Kau…',
#  'RT @sharetrainKA2: The agenda for 2nd transnational meeting  in @KaunoPkc KaunoPkc #Kaunas #Lithuania #Lietuva  is ready  Looking forward t…',
#  'RT @NejauNet: Shadow | #Kaunas, #Lithuania #mavicpro #Lietuva #dronas #beautifullithuania #mavic #djimavic #djieurope #Kaunascity #Kaunasae…']

# %%
# Show one sample search result by slicing the list...
print(json.dumps(statuses[4], indent=1))
# Out:
# {
#  "created_at": "Tue Apr 24 09:30:39 +0000 2018",
#  "id": 988711810751778816,
#  "id_str": "988711810751778816",
#  "text": "Veiksme | in action \ud83d\ude0e\n\u2022\n\u2022\n\u2022\n\u2022\n\u2022\n\u2022\n\u2022\n#me #choreographer #choreografas #vilonas #lietuva\u2026 https://t.co/UMvp0ml9xf",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "me",
#     "indices": [
#      36,
#      39
#     ]
#    },
#    {
#     "text": "choreographer",
#     "indices": [
#      40,
#      54
#     ]
#    },
#    {
#     "text": "choreografas",
#     "indices": [
#      55,
#      68
#     ]
#    },
#    {
#     "text": "vilonas",
#     "indices": [
#      69,
#      77
#     ]
#    },
#    {
#     "text": "lietuva",
#     "indices": [
#      78,
#      86
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [],
#   "urls": [
#    {
#     "url": "https://t.co/UMvp0ml9xf",
#     "expanded_url": "https://www.instagram.com/p/Bh8r7jHA6lu/",
#     "display_url": "instagram.com/p/Bh8r7jHA6lu/",
#     "indices": [
#      88,
#      111
#     ]
#    }
#   ]
#  },
#  "metadata": {
#   "iso_language_code": "nl",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://instagram.com\" rel=\"nofollow\">Instagram</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 2302909332,
#   "id_str": "2302909332",
#   "name": "Paulius \u0160ink\u016bnas",
#   "screen_name": "PauliusSin",
#   "location": "Vilnius, Lithuania",
#   "description": "Choreographer and poker player #youheardme",
#   "url": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 24,
#   "friends_count": 16,
#   "listed_count": 1,
#   "created_at": "Tue Jan 21 11:05:16 +0000 2014",
#   "favourites_count": 116,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": true,
#   "verified": false,
#   "statuses_count": 76,
#   "lang": "en",
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "C0DEED",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/898237248247824385/qKiF-i6t_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/898237248247824385/qKiF-i6t_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/2302909332/1502991424",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": true,
#   "default_profile": true,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "is_quote_status": false,
#  "retweet_count": 0,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "possibly_sensitive": false,
#  "lang": "nl"
# }

# %%
# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = statuses[0]
#[ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'])
print(t['retweeted'])
# Out:
# 4
# False

# %%
print(json.dumps(status_texts[0:5], indent=1))

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# %%
# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "#ArianaComeToLithuania #Vilnius #Kaunas #Lietuva #Lithuania Listen on @Spotify  #NoTearsLeftToCry by @ArianaGrande \u2661 https://t.co/Jbzq0rYvja",
#  "#like4like #palanga #vilnius #lithuanian #litva #lietuva #lucky #luxurylife #europe #mafia\u2026 https://t.co/0Nn8rkVK0g",
#  "#Birstonas #Lithuania spring time #lietuva https://t.co/aQ9IdWaDG0",
#  "RT @WeLoveLithuania: Sakur\u0173 \u017eyd\u0117jimas Vilniuje 2018 \u2013 Vakarin\u0117 versija\n#Vilnius\nWe love Lithuania - Photo by: Simonas Rudaminas\n#Lithuania\u2026",
#  "Veiksme | in action \ud83d\ude0e\n\u2022\n\u2022\n\u2022\n\u2022\n\u2022\n\u2022\n\u2022\n#me #choreographer #choreografas #vilonas #lietuva\u2026 https://t.co/UMvp0ml9xf"
# ]
# [
#  "Spotify",
#  "ArianaGrande",
#  "WeLoveLithuania",
#  "NejauNet",
#  "NejauNet"
# ]
# [
#  "ArianaComeToLithuania",
#  "Vilnius",
#  "Kaunas",
#  "Lietuva",
#  "Lithuania"
# ]
# [
#  "#ArianaComeToLithuania",
#  "#Vilnius",
#  "#Kaunas",
#  "#Lietuva",
#  "#Lithuania"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()
# Out:
# [('#Lietuva', 32), ('#Lithuania', 31), ('RT', 19), ('of', 12), ('@Confederation_M:', 11), ('the', 10), ('VADOVAS', 10), ('|', 9), ('#lietuva', 8), ('#mavicpro', 8)]
#
# [('Confederation_M', 11), ('NejauNet', 4), ('Spotify', 2), ('ArianaGrande', 2), ('WeLoveLithuania', 1), ('ValstietisToday', 1), ('ArianaGrandeLT4', 1), ('IIHFHockey', 1), ('NJDevils', 1), ('NYRangers', 1)]
#
# [('Lietuva', 33), ('Lithuania', 32), ('Kaunas', 15), ('Vilnius', 11), ('lietuva', 10), ('mavicpro', 8), ('dronas', 8), ('beautifullithuania', 8), ('mavic', 8), ('djimavic', 7)]

# %% [markdown]
# ## Example 8. Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])
# Out:
#         Word         | Count
# ****************************************
# #Lietuva             |     32
# #Lithuania           |     31
# RT                   |     19
# of                   |     12
# @Confederation_M:    |     11
# the                  |     10
# VADOVAS              |     10
# |                    |      9
# #lietuva             |      8
# #mavicpro            |      8
#
#     Screen Name      | Count
# ****************************************
# Confederation_M      |     11
# NejauNet             |      4
# Spotify              |      2
# ArianaGrande         |      2
# WeLoveLithuania      |      1
# ValstietisToday      |      1
# ArianaGrandeLT4      |      1
# IIHFHockey           |      1
# NJDevils             |      1
# NYRangers            |      1
#
#       Hashtag        | Count
# ****************************************
# Lietuva              |     33
# Lithuania            |     32
# Kaunas               |     15
# Vilnius              |     11
# lietuva              |     10
# mavicpro             |      8
# dronas               |      8
# beautifullithuania   |      8
# mavic                |      8
# djimavic             |      7

# %% [markdown]
# ## Example 9. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*60)
    for count, screen_name, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50]))
        if len(text) > 50:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
# Slice off the first 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse=True)[:10])
# Out:
#  Count  |   Screen Name   | Text
# ************************************************************
#   14    |  sharetrainKA2  | RT @sharetrainKA2: The agenda for 2nd transnationa
#         |                 | l meeting  in @KaunoPkc KaunoPkc #Kaunas #Lithuani
#         |                 | a #Lietuva  is ready  Looking forward t…
#    8    | Confederation_M | RT @Confederation_M: #Energetikos Departamento VAD
#         |                 | OVAS (#Vilnius)\Head of the #Energy (#LPG, #oil) D
#         |                 | epartment \#Lithuania #Lietuva #Литва #…
#    8    | Confederation_M | RT @Confederation_M: #Eksporto Departamento VADOVA
#         |                 | S (#Vilnius, #Kaunas)\Head of the #Export Departme
#         |                 | nt\#Lithuania #Lietuva #Литва @Confeder…
#    7    | Confederation_M | RT @Confederation_M: Vacancies: \#Nekilnojamojo tu
#         |                 | rto Departamento VADOVAS (#Vilnius, #Kaunas)\Head
#         |                 | of the #RealEstate Department\#Lithuani…
#    7    | Confederation_M | RT @Confederation_M: Vacancies of the National Con
#         |                 | federation of Marketing, Sales and Service Profess
#         |                 | ionals - MPA Konfederacijai aktualu \#L…
#    7    | Confederation_M | RT @Confederation_M: #Statybų ir remonto Departame
#         |                 | nto VADOVAS (#Vilnius, #Kaunas, #Klaipėda)\Head of
#         |                 |  the #Building and #Repair Department\#…
#    7    | Confederation_M | RT @Confederation_M: #NewMarkets Departamento VADO
#         |                 | VAS (#Vilnius, #Kaunas, #Klaipėda)\Head of the New
#         |                 | Market Department\#Lithuania #Lietuva #…
#    7    | Confederation_M | RT @Confederation_M: #HoReCa Departamento VADOVAS
#         |                 | (#Kaunas, #Vilnius )\Head of the HoReCa Department
#         |                 | \#Lithuania #Lietuva #Литва #MPA_Konfed…
#    6    | Confederation_M | RT @Confederation_M: Vacancies:\GR Departamento VA
#         |                 | DOVAS (#Vilnius)\Head of the #GR Department \#Lith
#         |                 | uania #Lietuva #Литва #MPA_Konfederacija
#    6    | Confederation_M | RT @Confederation_M: Mokymo Centro VADOVAS (Vilniu
#         |                 | s, Kaunas)\Apmokymų, įgūdžių ugdymo ir profesinio
#         |                 | meistriškumo tobulinimo Centras – MPA K…
